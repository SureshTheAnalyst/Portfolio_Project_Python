# %% [markdown]
# # Data analysis using Covid-19 dataset with python.
# ## The data contains daily confirmed cases and daily death cases for 100 days from January 22, 2020 to April 30, 2020.
# ------------------------------------------

# %% [markdown]
# ### 1. First, let's import the necessary modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ### 2. Importing covid-19 dataset

# %%
corona_dataset_csv = pd.read_csv("covid19_confirmed_dataset.csv")
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# ### 2. Delete the non-essential columns

# %%
df = corona_dataset_csv.drop(["Lat", "Long", "Province/State"], axis = 1)

# %%
df.head(10)
# Out:
#         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          Afghanistan        0        0        0        0        0        0
# 1              Albania        0        0        0        0        0        0
# 2              Algeria        0        0        0        0        0        0
# 3              Andorra        0        0        0        0        0        0
# 4               Angola        0        0        0        0        0        0
# 5  Antigua and Barbuda        0        0        0        0        0        0
# 6            Argentina        0        0        0        0        0        0
# 7              Armenia        0        0        0        0        0        0
# 8            Australia        0        0        0        0        0        0
# 9            Australia        0        0        0        0        3        4
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# ...

# %% [markdown]
# ### 3. Aggregating the rows by the country

# %%
corona_dataset_aggregated = df.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %% [markdown]
# #### Checking the shape again

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# ### 4. Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
corona_dataset_aggregated.dtypes
# Out:
# 1/22/20    int64
# 1/23/20    int64
# 1/24/20    int64
# 1/25/20    int64
# 1/26/20    int64
#            ...
# 4/26/20    int64
# 4/27/20    int64
# 4/28/20    int64
# 4/29/20    int64
# 4/30/20    int64
# Length: 100, dtype: object

# %%
corona_dataset_aggregated.loc["China"].plot()
# Out:
# <Axes: >

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["India"].plot()
corona_dataset_aggregated.loc["Canada"].plot()
plt.legend()

# %% [markdown]
# ### 5. Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc["China"][:3].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 6. Caculating and plotting the first derivative of the curve

# %%
corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
corona_dataset_aggregated.loc["China"].diff().plot()
corona_dataset_aggregated.loc["India"].diff().plot()
corona_dataset_aggregated.loc["US"].diff().plot()
plt.legend()

# %% [markdown]
# ### 7. Finding maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
corona_dataset_aggregated.loc["US"].diff().max()
# Out:
# 36188.0

# %% [markdown]
# ### 8. Finding maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
max_infection_rates
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %% [markdown]
# ### 9. Inserting this into a new column

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["max_infection_rate"] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# ### 10. Creating a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# ### 11. Repeating all the same steps above for the covid-19 death rate
# - importing the csv file,
# - calculating the differntial daily death rate,
# - keeping only necessary columns

# %%
corona_dataset_death = pd.read_csv("covid19_deaths_dataset.csv")
corona_dataset_death.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...       36
# ...

# %%
corona_dataset_death.shape
# Out:
# (266, 104)

# %%
df2 = corona_dataset_death.drop(["Lat", "Long", "Province/State"], axis = 1)

# %%
df2.head(10)
# Out:
#         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          Afghanistan        0        0        0        0        0        0
# 1              Albania        0        0        0        0        0        0
# 2              Algeria        0        0        0        0        0        0
# 3              Andorra        0        0        0        0        0        0
# 4               Angola        0        0        0        0        0        0
# 5  Antigua and Barbuda        0        0        0        0        0        0
# 6            Argentina        0        0        0        0        0        0
# 7              Armenia        0        0        0        0        0        0
# 8            Australia        0        0        0        0        0        0
# 9            Australia        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# ...

# %%
corona_dataset_death_aggregated = df2.groupby("Country/Region").sum()

# %%
corona_dataset_death_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       36       40       42
# Albania               0        0        0  ...       26       27       27
# Algeria               0        0        0  ...      392      402      407
# Andorra               0        0        0  ...       37       37       37
# ...

# %%
corona_dataset_death_aggregated.shape
# Out:
# (187, 100)

# %%
corona_dataset_death_aggregated.loc["China"].plot()
# Out:
# <Axes: >

# %%
corona_dataset_death_aggregated.loc["China"].plot()
corona_dataset_death_aggregated.loc["India"].plot()
corona_dataset_death_aggregated.loc["Canada"].plot()
plt.legend()

# %%
corona_dataset_death_aggregated.loc["China"][:30].plot()
# Out:
# <Axes: >

# %%
corona_dataset_death_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
corona_dataset_death_aggregated.loc["China"].diff().plot()
corona_dataset_death_aggregated.loc["India"].diff().plot()
corona_dataset_death_aggregated.loc["US"].diff().plot()
plt.legend()

# %%
corona_dataset_death_aggregated.loc["China"].diff().max()
# Out:
# 1290.0

# %%
corona_dataset_death_aggregated.loc["India"].diff().max()
# Out:
# 75.0

# %%
corona_dataset_death_aggregated.loc["US"].diff().max()
# Out:
# 2612.0

# %%
countries = list(corona_dataset_death_aggregated.index)
max_death_rates = []
for c in countries:
    max_death_rates.append(corona_dataset_death_aggregated.loc[c].diff().max())
max_death_rates
# Out:
# [7.0,
#  4.0,
#  30.0,
#  4.0,
#  2.0,
#  1.0,
#  13.0,
#  3.0,
#  8.0,
#  30.0,
#  3.0,
#  3.0,
#  1.0,
#  15.0,
#  1.0,
#  5.0,
#  496.0,
#  1.0,
#  1.0,
#  0.0,
#  6.0,
#  6.0,
#  1.0,
#  493.0,
#  1.0,
#  6.0,
#  4.0,
#  2.0,
#  1.0,
#  1.0,
#  0.0,
#  20.0,
#  251.0,
#  0.0,
#  3.0,
#  13.0,
#  1290.0,
#  26.0,
#  0.0,
#  3.0,
#  5.0,
#  1.0,
#  4.0,
#  8.0,
#  6.0,
#  2.0,
#  18.0,
#  22.0,
#  2.0,
#  1.0,
#  0.0,
#  38.0,
#  208.0,
#  22.0,
#  1.0,
#  1.0,
#  0.0,
#  6.0,
#  1.0,
#  2.0,
#  0.0,
#  43.0,
#  1440.0,
#  1.0,
#  1.0,
#  1.0,
#  510.0,
#  5.0,
#  10.0,
#  0.0,
#  3.0,
#  2.0,
#  1.0,
#  2.0,
#  2.0,
#  0.0,
#  8.0,
#  23.0,
#  5.0,
#  75.0,
#  60.0,
#  158.0,
#  7.0,
#  220.0,
#  13.0,
#  919.0,
#  2.0,
#  47.0,
#  2.0,
#  5.0,
#  2.0,
#  11.0,
#  10.0,
#  4.0,
#  3.0,
#  0.0,
#  4.0,
#  2.0,
#  4.0,
#  1.0,
#  1.0,
#  6.0,
#  8.0,
#  2.0,
#  0.0,
#  1.0,
#  8.0,
#  1.0,
#  4.0,
#  1.0,
#  1.0,
#  2.0,
#  163.0,
#  10.0,
#  2.0,
#  0.0,
#  1.0,
#  12.0,
#  0.0,
# ...

# %%
countries = list(corona_dataset_death_aggregated.index)
max_death_rates = []
for c in countries:
    max_death_rates.append(corona_dataset_death_aggregated.loc[c].diff().max())
corona_dataset_death_aggregated["max_death_rate"] = max_death_rates

# %%
corona_dataset_death_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %%
corona_death_data = pd.DataFrame(corona_dataset_death_aggregated["max_death_rate"])

# %%
corona_death_data.head()
# Out:
#                 max_death_rate
# Country/Region
# Afghanistan                7.0
# Albania                    4.0
# Algeria                   30.0
# Andorra                    4.0
# Angola                     2.0

# %% [markdown]
# ### Next, we are
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - joining the datasets
# - calculating the correlations as the result of our analysis

# %% [markdown]
# ### 12. Importing the WorldHappinessReport.csv dataset

# %%
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### 13. Let's drop the unnecessary columns

# %%
drop_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]

# %%
happiness_report = happiness_report_csv.drop(drop_cols, axis=1)
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### 14. Changing the indices of the dataframe

# %%
happiness_report = happiness_report.set_index("Country or region")

# %%
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### 15. Let's join two dataset we have prepared

# %%
data = corona_data.join(happiness_report, how="inner")
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
data.shape
# Out:
# (143, 5)

# %% [markdown]
# ### 16. Combine another table

# %%
combined = corona_death_data.join(data, how="inner")
combined.head()
# Out:
#              max_death_rate  max_infection_rate  GDP per capita  \
# Afghanistan             7.0               232.0           0.350
# Albania                 4.0                34.0           0.947
# Algeria                30.0               199.0           1.002
# Argentina              13.0               291.0           1.092
# Armenia                 3.0               134.0           0.850
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.517                    0.361
# Albania               0.848                    0.874
# Algeria               1.160                    0.785
# Argentina             1.432                    0.881
# Armenia               1.055                    0.815
#
#              Freedom to make life choices
# Afghanistan                         0.000
# Albania                             0.383
# Algeria                             0.086
# Argentina                           0.471
# Armenia                             0.283

# %% [markdown]
# ### 17. correlation matrix

# %%
combined.corr()
# Out:
#                               max_death_rate  max_infection_rate  \
# max_death_rate                      1.000000            0.880597
# max_infection_rate                  0.880597            1.000000
# GDP per capita                      0.259893            0.250118
# Social support                      0.204148            0.191958
# Healthy life expectancy             0.309666            0.289263
# Freedom to make life choices        0.080166            0.078196
#
#                               GDP per capita  Social support  \
# max_death_rate                      0.259893        0.204148
# max_infection_rate                  0.250118        0.191958
# GDP per capita                      1.000000        0.759468
# Social support                      0.759468        1.000000
# Healthy life expectancy             0.863062        0.765286
# Freedom to make life choices        0.394603        0.456246
#
#                               Healthy life expectancy  \
# ...

# %% [markdown]
# ### 18. Visualizing the results
# Our analysis is not finished. We need to visualize the results so that everyone can understand what we got out of our analysis.

# %%
combined.head()
# Out:
#              max_death_rate  max_infection_rate  GDP per capita  \
# Afghanistan             7.0               232.0           0.350
# Albania                 4.0                34.0           0.947
# Algeria                30.0               199.0           1.002
# Argentina              13.0               291.0           1.092
# Armenia                 3.0               134.0           0.850
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.517                    0.361
# Albania               0.848                    0.874
# Algeria               1.160                    0.785
# Argentina             1.432                    0.881
# Armenia               1.055                    0.815
#
#              Freedom to make life choices
# Afghanistan                         0.000
# Albania                             0.383
# Algeria                             0.086
# Argentina                           0.471
# Armenia                             0.283

# %% [markdown]
# ### 18.1 Plotting GDP vs maximum Infection rate & maximum death rate

# %%
sns.scatterplot(x=combined["GDP per capita"], y=combined["max_infection_rate"])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.scatterplot(x=combined["GDP per capita"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_death_rate'>

# %% [markdown]
# ### 18.2 Let's change it to log scale and draw a linear regression model fit

# %%
sns.scatterplot(x=combined["GDP per capita"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.scatterplot(x=combined["GDP per capita"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_death_rate'>

# %%
sns.regplot(x=combined["GDP per capita"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.regplot(x=combined["GDP per capita"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_death_rate'>

# %% [markdown]
# ### 18.3 Plotting Social support vs maximum Infection rate & maximum death rate

# %%
sns.scatterplot(x=combined["Social support"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='Social support', ylabel='max_infection_rate'>

# %%
sns.scatterplot(x=combined["Social support"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='Social support', ylabel='max_death_rate'>

# %%
sns.regplot(x=combined["Social support"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='Social support', ylabel='max_infection_rate'>

# %%
sns.regplot(x=combined["Social support"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='Social support', ylabel='max_death_rate'>

# %% [markdown]
# ### 18.4 Plotting Healthy life expectancy vs maximum Infection rate & maximum death rate

# %%
sns.scatterplot(x=combined["Healthy life expectancy"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
sns.scatterplot(x=combined["Healthy life expectancy"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_death_rate'>

# %%
sns.regplot(x=combined["Healthy life expectancy"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
sns.regplot(x=combined["Healthy life expectancy"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_death_rate'>

# %% [markdown]
# ### 18.5 Plotting Freedom to make life choices vs maximum Infection rate & maximum death rate

# %%
sns.scatterplot(x=combined["Freedom to make life choices"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_infection_rate'>

# %%
sns.scatterplot(x=combined["Freedom to make life choices"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_death_rate'>

# %%
sns.regplot(x=combined["Freedom to make life choices"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_infection_rate'>

# %%
sns.regplot(x=combined["Freedom to make life choices"], y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_death_rate'>

# %% [markdown]
# ### 18.6 Plotting maximum infection rate vs maximum death rate

# %%
sns.scatterplot(x=combined["max_death_rate"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='max_death_rate', ylabel='max_infection_rate'>

# %%
sns.scatterplot(x=combined["max_death_rate"], y=np.log(combined["max_infection_rate"]))
# Out:
# <Axes: xlabel='max_death_rate', ylabel='max_infection_rate'>

# %%
sns.regplot(x=np.log(combined["max_infection_rate"]), y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='max_infection_rate', ylabel='max_death_rate'>

# %%
sns.regplot(x=np.log(combined["max_infection_rate"]), y=combined["max_death_rate"])
# Out:
# <Axes: xlabel='max_infection_rate', ylabel='max_death_rate'>
